# %%
# Basic If-Else Practice Questions
# 1 Even or Odd - Write a program to check whether a number is even or odd.
# 2 Positive, Negative, or Zero - Check if a given number is positive, negative, or zero.
# 3 Greatest of Two Numbers - Find the largest number between two numbers.
# 4 Voting Eligibility - Take the user’s age and check if they are eligible to vote (age ≥ 18).
# 5 Check Leap Year - Write a program to check whether a year is a leap year.
# 6 Pass or Fail - If marks ≥ 35 → Pass, else → Fail.
# 7 Pass or Fail - If marks ≥ 35 → Pass, else → Fail.
# 8 Character Type Check -Input a character and check if it is a vowel or consonant.
# 9 Largest of Three Numbers - Find the largest among three numbers using if-elif-else.
# 10 Grade System - Input marks and print grade: 90–100 → A ,80–89 → B ,70–79 → C ,below 70 → D

# 1 
num = 3
if num % 2 == 0:
    print('number is positive')
else:
    print('number is  negative')


# 2
numb = -1
if numb > 0:
    print('Number is postive')
else:
    print('Number is Negative')


# 3 Identify greater number 
a = 5
b = 6
if a > b:
    print(a,'is greater number')
else:
    print(b,'is greater number')

# 3 Idenntify smaller number
a = 5
b = 10
if a < b:
    print(a,'is smaller number')
elif a == b:
    print('both number are same')
else:
    print(b,'is smaller number')

# 4 
Age = 17
if (Age >= 18):
    print('Is Eligible for voting')
else:
    print('Not-Eligible for Voting')

# 5
year = 2028
if (year % 4 ==0 and num % 100!= 0 ) or (num%400 == 0):
    print(year,'Is Leap Year')
else:
    print(year,'Is Not a leap Year')

# 6/7
marks = 35

if marks >= 35:
    print('Pass')
else:
    print('Fail')


# 8
a1 = ['a','e','i','o','u']
a2 = 'A'
if a2.lower() in a1:                             # Lower indicates the value is in Capital (A) or Small (a)
    print(' vovel is present')
else:
    print('constant is present')


# 9 
a1 = 2
a2 = 6
a3 = 4

if a1 > a2:
    print(a1,'is greater number')
elif a2 > a3:
    print(a2,'is greater number')
else:
    print(a3,'is greater number')
 
# 10 

marks = 65

if marks >=90 and marks <=100:                     # and operator only used when both condition are true
    print('Grade - A')
elif marks >= 80 and marks <= 85:
    print('Grade - B')
elif marks >= 70 and marks <= 79:
    print('Grade - C')
else:
    print('Grade - D' )
# Out:
# number is  negative
# Number is Negative
# 6 is greater number
# 5 is smaller number
# Not-Eligible for Voting
# 2028 Is Leap Year
# Pass
#  vovel is present
# 6 is greater number
# Grade - D
