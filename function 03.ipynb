# %%
# Intermediate Level

#(Use conditions and arithmetic together)
# 7. Odd or Even – Check if a number is even or odd using %.
# 8. Positive, Negative, or Zero – Check if a number is positive, negative, or zero.
# 9. Leap Year Check – Use arithmetic and logical operators to check leap year.
# 10. Sum of Digits – Input a 3-digit number (e.g. 123 → 1+2+3=6).
# 11. Reverse a Number – Input 123 → Output 321.
# 12. Multiplication Table – Print multiplication table of any number (1 to 10).
# 13. Area & Perimeter of Circle – Input radius, calculate both.
# 14. Temperature Converter – Convert Celsius ↔ Fahrenheit.
# 15. Check Divisibility – Check if a number is divisible by 2 and 3 both.

# 7
a = 10
if a % 2 == 0:
    print('even')
else:
    print('odd')

# 8 (already solved question)
# 9 (already solved question)

year = 2032

if (year % 400 == 0 and year % 100 != 0) or year % 4 ==0:
    print('leap year')
else:
    print('not an leap year')

if year % 4 ==0:
    print('leap year')
else:
    print('not an leap year')

# 10 (dought) 
# 11 (dought)

# 12
num = 10
for i in range (1,11):
   # print(num * i)
    print(num,'x' ,i, '=',num*i)

# 13
r = 10
pi = 3.14159         # π(pi value) = 314159
area = pi* (r**2)
perimeter = 2* pi * r       #Perimeter (Circumference)=2×π×r

print('Area of Circle :', area)
print('Perimeter of Circle :', perimeter)

# 14 (just understand )

# 15

num = 12

if num % 2 == 0 and num % 3 == 0:
    print('number is divisible by 2 and 3')
else:
    print('number is not-divisible by 2 and 3')
# Out:
# even
# leap year
# leap year
# 10 x 1 = 10
# 10 x 2 = 20
# 10 x 3 = 30
# 10 x 4 = 40
# 10 x 5 = 50
# 10 x 6 = 60
# 10 x 7 = 70
# 10 x 8 = 80
# 10 x 9 = 90
# 10 x 10 = 100
# Area of Circle : 314.159
# Perimeter of Circle : 62.8318
# number is divisible by 2 and 3
